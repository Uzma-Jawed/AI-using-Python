# %% [markdown]
# <a href="https://colab.research.google.com/github/Uzma-Jawed/AI-using-Python/blob/main/AIusingPythonEx1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Uzma Jawed
#
#
# ---
#
# **✅ Task 1: Salary Tax Calculator**

# %%
# Task 1

salary = int(input("enter your salary: "))

if salary <= 30000:
    print("Tax rate is 5 %")

elif salary >30000 and salary <= 70000:
    print("Tax rate is 15% ")

else:
    print("Tax rate is 25%")
# Out:
# enter your salary: 100000
# Tax rate is 25%

# %% [markdown]
# **✅ Task 2: Word Length Dictionary**

# %%
# Task 2

fruits = ["apple", "banana", "kiwi", "cherry", "mango"]

fruits_dict = {word: len(word) for word in fruits}

print(fruits_dict)
# Out:
# {'apple': 5, 'banana': 6, 'kiwi': 4, 'cherry': 6, 'mango': 5}

# %% [markdown]
# **✅ Task 3: Chat System (OOP)**

# %%
# Task 3

class User:
    def __init__(self, name):
        self.name = name

    def send_message(self, chatroom, content):
        message = Message(self, content)
        chatroom.add_message(message)


class Message:
    def __init__(self, user, content):
        self.user = user
        self.content = content


class ChatRoom:
    def __init__(self):
        self.users = []
        self.messages = []

    def join(self, user):
        self.users.append(user)
        print(f"{user.name} joined the chat.")

    def leave(self, user):
        self.users.remove(user)
        print(f"{user.name} left the chat.")

    def add_message(self, message):
        self.messages.append(message)
        print(f"{message.user.name}: {message.content}")

    def show_chat_history(self):
        print("\n--- Chat History ---")
        for msg in self.messages:
            print(f"{msg.user.name}: {msg.content}")


# --- Testing the system ---

chatroom = ChatRoom()

user1 = User("Uzma")
user2 = User("Arshad")
user3 = User("Zaid")

chatroom.join(user1)
chatroom.join(user2)
chatroom.join(user3)

user1.send_message(chatroom, "Hello!")
user2.send_message(chatroom, "Hi Uzma!")
user3.send_message(chatroom, "How are you?")
user1.send_message(chatroom, "I'm fine, thanks!")

chatroom.show_chat_history()

chatroom.leave(user2)
# Out:
# Uzma joined the chat.
# Arshad joined the chat.
# Zaid joined the chat.
# Uzma: Hello!
# Arshad: Hi Uzma!
# Zaid: How are you?
# Uzma: I'm fine, thanks!
#
# --- Chat History ---
# Uzma: Hello!
# Arshad: Hi Uzma!
# Zaid: How are you?
# Uzma: I'm fine, thanks!
# Arshad left the chat.
